# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("euro2024_players.csv")
df = data[data["Country"] == "Turkiye"]

# %%
df.head()
# Out:
#                 Name     Position  Age               Club  Height   Foot  \
# 519   Altay Bayındır   Goalkeeper   26  Manchester United     198  right
# 520    Uğurcan Çakır   Goalkeeper   28        Trabzonspor     191  right
# 521       Mert Günok   Goalkeeper   35        Besiktas JK     196  right
# 522    Merih Demiral  Centre-Back   26        Al-Ahli SFC     190  right
# 523  Ahmetcan Kaplan  Centre-Back   21     Ajax Amsterdam     189   left
#
#      Caps  Goals  MarketValue  Country
# 519     9      0     10000000  Turkiye
# 520    27      0      8000000  Turkiye
# 521    28      0      1200000  Turkiye
# 522    43      2     16000000  Turkiye
# 523     0      0     10000000  Turkiye

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 519 to 544
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         26 non-null     object
#  1   Position     26 non-null     object
#  2   Age          26 non-null     int64
#  3   Club         26 non-null     object
#  4   Height       26 non-null     int64
#  5   Foot         26 non-null     object
#  6   Caps         26 non-null     int64
#  7   Goals        26 non-null     int64
#  8   MarketValue  26 non-null     int64
#  9   Country      26 non-null     object
# dtypes: int64(5), object(5)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#              Age      Height       Caps      Goals   MarketValue
# count  26.000000   26.000000  26.000000  26.000000  2.600000e+01
# mean   25.807692  183.923077  24.307692   2.730769  1.246538e+07
# std     4.223925    6.956569  20.586926   4.984437  1.056719e+07
# min    18.000000  173.000000   0.000000   0.000000  1.200000e+06
# 25%    23.250000  178.500000   7.500000   0.250000  4.775000e+06
# 50%    26.000000  184.000000  20.000000   1.000000  1.000000e+07
# 75%    28.750000  189.750000  37.000000   2.000000  1.575000e+07
# max    35.000000  198.000000  85.000000  20.000000  4.500000e+07

# %%
df["Name"].unique()
# Out:
# array(['Altay Bayındır', 'Uğurcan Çakır', 'Mert Günok', 'Merih Demiral',
#        'Ahmetcan Kaplan', 'Abdülkerim Bardakcı', 'Kaan Ayhan',
#        'Samet Akaydin', 'Ferdi Kadıoğlu', 'Zeki Çelik', 'Mert Müldür',
#        'Hakan Çalhanoğlu', 'İsmail Yüksek', 'Salih Özcan', 'Okay Yokuşlu',
#        'Orkun Kökçü', 'Arda Güler', 'Yusuf Yazıcı', 'Kerem Aktürkoğlu',
#        'Barış Alper Yılmaz', 'İrfan Can Kahveci', 'Yunus Akgün',
#        'Kenan Yıldız', 'Semih Kılıçsoy', 'Bertuğ Yıldırım', 'Cenk Tosun'],
#       dtype=object)

# %%
df["Name"].nunique()
# Out:
# 26

# %%
df.groupby("Name")["Goals"].max()
# Out:
# Name
# Abdülkerim Bardakcı     1
# Ahmetcan Kaplan         0
# Altay Bayındır          0
# Arda Güler              1
# Barış Alper Yılmaz      1
# Bertuğ Yıldırım         2
# Cenk Tosun             20
# Ferdi Kadıoğlu          1
# Hakan Çalhanoğlu       18
# Kaan Ayhan              5
# Kenan Yıldız            1
# Kerem Aktürkoğlu        5
# Merih Demiral           2
# Mert Günok              0
# Mert Müldür             1
# Okay Yokuşlu            1
# Orkun Kökçü             2
# Salih Özcan             0
# Samet Akaydin           0
# Semih Kılıçsoy          0
# Uğurcan Çakır           0
# Yunus Akgün             2
# Yusuf Yazıcı            3
# Zeki Çelik              2
# İrfan Can Kahveci       2
# İsmail Yüksek           1
# Name: Goals, dtype: int64

# %%
sns.displot(x="Height",data=df,color="red",kde=True)
plt.title("Turkish Players Height Distribution")
plt.xlabel("Heights")
plt.show()
